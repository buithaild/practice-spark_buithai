# %%
from pyspark.sql import SparkSession
spark = SparkSession. \
builder. \
master("local[*]"). \
appName("Write data"). \
getOrCreate()

# %%
order_schema = "order_id long, order_date string, customer_id long, order_status string"

# %%
df = spark.read \
.format("csv") \
.schema(order_schema) \
.load("D:\Learn-spark\learn-spark-maide\orders_large.csv")

# %%
#overwrite
df.write \
.format("csv") \
.mode("overwrite") \
.option("path", "D:\Learn-spark\learn-spark-maide\write-data-in-spark\demo1") \
.save()

# %%
df.rdd.getNumPartitions()
# Out:
# 12

# %% [markdown]
# Nên có 12 file csv được tạo ra,
# file csv.crc: được tạo cùng ra, không ảnh hưởng gì (cơ chế đảm bảo toàn vẹn ấy mà :)

# %%
#Bỏ format đi thì sao???
df.write \
.mode("overwrite") \
.option("path", "D:\Learn-spark\learn-spark-maide\write-data-in-spark\demo2") \
.save()

# %%
#ignore
df.write \
.mode("ignore") \
.option("path", "D:\Learn-spark\learn-spark-maide\write-data-in-spark\demo2") \
.save()

# %%
#append
df.write \
.mode("append") \
.option("path", "D:\Learn-spark\learn-spark-maide\write-data-in-spark\demo2") \
.save()
## Đang có 12 file, nếu apprnd vào thì sẽ thành 24 file

# %%
#errorIfExists
df.write \
.mode("errorIfExists") \
.option("path", "D:\Learn-spark\learn-spark-maide\write-data-in-spark\demo2") \
.save()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[14], line 5
#       1 #errorIfExists
#       2 df.write \
#       3 .mode("errorIfExists") \
#       4 .option("path", "D:\Learn-spark\learn-spark-maide\write-data-in-spark\demo2") \
# ----> 5 .save()
#
# File d:\Learn-spark\learn-spark-maide\.venv\Lib\site-packages\pyspark\sql\readwriter.py:1461, in DataFrameWriter.save(self, path, format, mode, partitionBy, **options)
#    1459     self.format(format)
#    1460 if path is None:
# -> 1461     self._jwrite.save()
#    1462 else:
#    1463     self._jwrite.save(path)
#
# File d:\Learn-spark\learn-spark-maide\.venv\Lib\site-packages\py4j\java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# ...
