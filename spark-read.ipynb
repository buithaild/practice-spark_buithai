# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark READ").getOrCreate()

# %%
orders_df = spark.read \
.format("csv") \
.option("header", "true") \
.option("inferSchema", "true") \
.load("./orders_wh.csv")

# %%
orders_df.show(5)
# Out:
# +--------+-------------------+-----------+---------------+
# |order_id|         order_date|customer_id|   order_status|
# +--------+-------------------+-----------+---------------+
# |       1|2013-07-25 00:00:00|      11599|         CLOSED|
# |       2|2013-07-25 00:00:00|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:00|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:00|       8827|         CLOSED|
# |       5|2013-07-25 00:00:00|      11318|       COMPLETE|
# +--------+-------------------+-----------+---------------+
# only showing top 5 rows

# %%
orders_df2 = spark.read.csv("./orders_wh.csv", header = "true", inferSchema = "true")

# %%
orders_df2.show(5)
# Out:
# +--------+-------------------+-----------+---------------+
# |order_id|         order_date|customer_id|   order_status|
# +--------+-------------------+-----------+---------------+
# |       1|2013-07-25 00:00:00|      11599|         CLOSED|
# |       2|2013-07-25 00:00:00|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:00|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:00|       8827|         CLOSED|
# |       5|2013-07-25 00:00:00|      11318|       COMPLETE|
# +--------+-------------------+-----------+---------------+
# only showing top 5 rows

# %%
#Tạo 1 bảng tạm và đặt tên cho bảng tạm đó: orders
orders_df.createOrReplaceTempView("orders")

# %%
df = spark.sql("select * from orders")

# %%
df.show(5)
# Out:
# +--------+-------------------+-----------+---------------+
# |order_id|         order_date|customer_id|   order_status|
# +--------+-------------------+-----------+---------------+
# |       1|2013-07-25 00:00:00|      11599|         CLOSED|
# |       2|2013-07-25 00:00:00|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:00|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:00|       8827|         CLOSED|
# |       5|2013-07-25 00:00:00|      11318|       COMPLETE|
# +--------+-------------------+-----------+---------------+
# only showing top 5 rows

# %%
df1 = spark.read.table("orders")

# %%
df1.show(5)
# Out:
# +--------+-------------------+-----------+---------------+
# |order_id|         order_date|customer_id|   order_status|
# +--------+-------------------+-----------+---------------+
# |       1|2013-07-25 00:00:00|      11599|         CLOSED|
# |       2|2013-07-25 00:00:00|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:00|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:00|       8827|         CLOSED|
# |       5|2013-07-25 00:00:00|      11318|       COMPLETE|
# +--------+-------------------+-----------+---------------+
# only showing top 5 rows
