# %%
from pyspark.sql import SparkSession
spark = SparkSession. \
builder. \
master("local[4]"). \
appName("Spark chia du lieu doc nhieu file"). \
getOrCreate()

# %%
orders_chema = "order_id long, order_date date, customer_id long, order_status string"

# %%
orders_df = spark.read \
.format("csv") \
.schema(orders_chema) \
.load("D:\Learn-spark\learn-spark-maide\orders_csv_12")

# %%
orders_df.count()
# Out:
# 12000000

# %%
#Kiem tra bang code
orders_df.rdd.getNumPartitions()
# Out:
# 6

# %%
spark.stop()
