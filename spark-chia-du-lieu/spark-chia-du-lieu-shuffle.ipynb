# %%
from pyspark.sql import SparkSession
spark = SparkSession. \
builder. \
master("local[4]"). \
appName("Spark chia du lieu"). \
getOrCreate()

# %%
orders_chema = "order_id long, order_date date, customer_id long, order_status string"

# %%
orders_df = spark.read \
.format("csv") \
.schema(orders_chema) \
.load("D:\Learn-spark\learn-spark-maide\orders_large.csv")

# %%
spark.conf.get("spark.sql.shuffle.partitions")
# Out:
# '200'

# %%
spark.conf.get("spark.sql.adaptive.enabled")
# Out:
# 'true'

# %%
spark.conf.set("spark.sql.adaptive.enabled", "true")

# %%
#Thu 1 ham white transformation
orders_df.distinct().count()
# Out:
# 25000000

# %%
#Kiem tra bang code
orders_df.rdd.getNumPartitions()
# Out:
# 9

# %%
spark.stop()
